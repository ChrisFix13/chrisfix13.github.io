# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop('Cabin', axis = 1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = df.fillna(value = df['Age'].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df = df.drop(['Name','PassengerId'], axis = 1)
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch            Ticket  \
# 0           0       3    male  22.000000      1      0         A/5 21171
# 1           1       1  female  38.000000      1      0          PC 17599
# 2           1       3  female  26.000000      0      0  STON/O2. 3101282
# 3           1       1  female  35.000000      1      0            113803
# 4           0       3    male  35.000000      0      0            373450
# ..        ...     ...     ...        ...    ...    ...               ...
# 886         0       2    male  27.000000      0      0            211536
# 887         1       1  female  19.000000      0      0            112053
# 888         0       3  female  29.699118      1      2        W./C. 6607
# 889         1       1    male  26.000000      0      0            111369
# 890         0       3    male  32.000000      0      0            370376
#
#         Fare Embarked
# 0     7.2500        S
# 1    71.2833        C
# ...

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %%
# Apparently I filled in a NaN with the data from the mean('Age'), I want to remove that data.
df['Embarked'].loc[51:70]
df.at[61, 'Embarked'] = 'S'
# df['Embarked'].loc[811:870]
# df.loc[829]
df.at[829, 'Embarked'] = 'S'
# df.loc[829]
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
print(df['Pclass'].value_counts())
df['Pclass'].value_counts().plot(kind = 'bar')
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df[['Pclass','Survived']].value_counts()
# Out:
# Pclass  Survived
# 3       0           372
# 1       1           136
# 3       1           119
# 2       0            97
#         1            87
# 1       0            80
# Name: count, dtype: int64

# %%
df[['Survived','Pclass','Embarked']].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived,Pclass,Embarked'>

# %% [markdown]
# Estoy experimentando con la data, quiero poder plotear la diferencia entre la gente que sobrevivio vs la que no sobrevivio.
# ### So, here I am stuck because the Test doesn't have 'Survived' column because that's exactly what I should be predicting... So I'm not sure how to follow this... Will have to ask Irem or the boys tomorrow!

# %%
x_train = df.drop('Survived', axis = 1)
y_train = df['Survived']

###########################
df_test = pd.read_csv('test.csv')
# df_test
# x_test = df_test.drop('Survived', axis = 1)
# y_test = df_test['Survived']

# print ('x_train size: ', x_train.shape)
# print ('y_train size: ', y_train.shape)
# print ('x_test size: ', x_test.shape)
# print ('y_test size: ', y_test.shape)
