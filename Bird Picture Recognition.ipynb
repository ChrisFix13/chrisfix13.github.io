# %%
# !pip install keras_preprocessing
# !pip install tensorflow
# Out:
# Collecting keras_preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.25.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)
# Installing collected packages: keras_preprocessing
# Successfully installed keras_preprocessing-1.1.2

# %%
# Import Data Science Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Tensorflow Libraries
from tensorflow import keras
from tensorflow.keras import layers,models
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model
from tensorflow.keras.layers.experimental import preprocessing

# System libraries
import zipfile
from pathlib import Path
import os.path
import os
import random

# Visualization Libraries
import matplotlib.cm as cm
import cv2
import seaborn as sns

sns.set_style('darkgrid')

# Metrics
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py

# Import series of helper functions for our notebook
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir, pred_and_plot
# Out:
# --2024-06-24 13:42:39--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2024-06-24 13:42:39 (97.6 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
BATCH_SIZE = 32
TARGET_SIZE = (224, 224)

# %%
# !kaggle datasets download -d gpiosenka/100-bird-species
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gpiosenka/100-bird-species
# License(s): CC0-1.0
# Downloading 100-bird-species.zip to /content
# 100% 1.95G/1.96G [00:16<00:00, 115MB/s]
# 100% 1.96G/1.96G [00:16<00:00, 129MB/s]

# %%
# Unzip the downloaded dataset
with zipfile.ZipFile('100-bird-species.zip', 'r') as zip_ref:
    zip_ref.extractall('100-bird-species')

# %%
# Walk through each directory
dataset = "/content/100-bird-species/train"
walk_through_dir(dataset);
# Out:
# There are 525 directories and 0 images in '/content/100-bird-species/train'.
# There are 0 directories and 183 images in '/content/100-bird-species/train/MASKED BOBWHITE'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/TOWNSENDS WARBLER'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/TIT MOUSE'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/GREAT POTOO'.
# There are 0 directories and 202 images in '/content/100-bird-species/train/RED TAILED HAWK'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/INCA TERN'.
# There are 0 directories and 200 images in '/content/100-bird-species/train/RED KNOT'.
# There are 0 directories and 181 images in '/content/100-bird-species/train/TREE SWALLOW'.
# There are 0 directories and 211 images in '/content/100-bird-species/train/WOOD THRUSH'.
# There are 0 directories and 187 images in '/content/100-bird-species/train/TAWNY FROGMOUTH'.
# There are 0 directories and 199 images in '/content/100-bird-species/train/GREY HEADED CHACHALACA'.
# There are 0 directories and 186 images in '/content/100-bird-species/train/RUBY CROWNED KINGLET'.
# There are 0 directories and 188 images in '/content/100-bird-species/train/BLACK VENTED SHEARWATER'.
# There are 0 directories and 196 images in '/content/100-bird-species/train/STRIATED CARACARA'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/OSPREY'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/NORTHERN CARDINAL'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/CAPPED HERON'.
# There are 0 directories and 195 images in '/content/100-bird-species/train/WILLOW PTARMIGAN'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/WHITE CRESTED HORNBILL'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/CINNAMON TEAL'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/SNOW PARTRIDGE'.
# There are 0 directories and 141 images in '/content/100-bird-species/train/MYNA'.
# There are 0 directories and 184 images in '/content/100-bird-species/train/BUFFLEHEAD'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/FLAME BOWERBIRD'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/RUDDY SHELDUCK'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/PURPLE GALLINULE'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/PURPLE MARTIN'.
# There are 0 directories and 166 images in '/content/100-bird-species/train/BANDED PITA'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/GAMBELS QUAIL'.
# There are 0 directories and 151 images in '/content/100-bird-species/train/SAND MARTIN'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/BLACK THROATED WARBLER'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/ROADRUNNER'.
# There are 0 directories and 182 images in '/content/100-bird-species/train/OILBIRD'.
# There are 0 directories and 190 images in '/content/100-bird-species/train/AUSTRALASIAN FIGBIRD'.
# There are 0 directories and 184 images in '/content/100-bird-species/train/SPOTTED WHISTLING DUCK'.
# There are 0 directories and 166 images in '/content/100-bird-species/train/PUFFIN'.
# There are 0 directories and 172 images in '/content/100-bird-species/train/RED SHOULDERED HAWK'.
# There are 0 directories and 191 images in '/content/100-bird-species/train/RED CROSSBILL'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/BLACK VULTURE'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/MOURNING DOVE'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/APAPANE'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/SAMATRAN THRUSH'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/GROVED BILLED ANI'.
# There are 0 directories and 188 images in '/content/100-bird-species/train/PHAINOPEPLA'.
# There are 0 directories and 146 images in '/content/100-bird-species/train/RED BELLIED PITTA'.
# There are 0 directories and 149 images in '/content/100-bird-species/train/CAPE MAY WARBLER'.
# There are 0 directories and 151 images in '/content/100-bird-species/train/VICTORIA CROWNED PIGEON'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/HELMET VANGA'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/EMPEROR PENGUIN'.
# There are 0 directories and 131 images in '/content/100-bird-species/train/TASMANIAN HEN'.
# There are 0 directories and 133 images in '/content/100-bird-species/train/CAPUCHINBIRD'.
# There are 0 directories and 142 images in '/content/100-bird-species/train/GANG GANG COCKATOO'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/BELTED KINGFISHER'.
# There are 0 directories and 209 images in '/content/100-bird-species/train/MERLIN'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/EVENING GROSBEAK'.
# There are 0 directories and 189 images in '/content/100-bird-species/train/RUFUOS MOTMOT'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/SPOON BILED SANDPIPER'.
# There are 0 directories and 168 images in '/content/100-bird-species/train/BLACK-THROATED SPARROW'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/FIRE TAILLED MYZORNIS'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/AVADAVAT'.
# There are 0 directories and 183 images in '/content/100-bird-species/train/BREWERS BLACKBIRD'.
# There are 0 directories and 173 images in '/content/100-bird-species/train/HORNED LARK'.
# There are 0 directories and 169 images in '/content/100-bird-species/train/GREAT KISKADEE'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/ALBATROSS'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/PINK ROBIN'.
# There are 0 directories and 263 images in '/content/100-bird-species/train/RUFOUS TREPE'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/CRESTED AUKLET'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/ALBERTS TOWHEE'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/BLACK THROATED BUSHTIT'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/RUFOUS KINGFISHER'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/PARUS MAJOR'.
# There are 0 directories and 233 images in '/content/100-bird-species/train/D-ARNAUDS BARBET'.
# There are 0 directories and 143 images in '/content/100-bird-species/train/GREY HEADED FISH EAGLE'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/LILAC ROLLER'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/BLONDE CRESTED WOODPECKER'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/CHESTNET BELLIED EUPHONIA'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/RUDY KINGFISHER'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/OKINAWA RAIL'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/RED WISKERED BULBUL'.
# There are 0 directories and 173 images in '/content/100-bird-species/train/BLACK NECKED STILT'.
# There are 0 directories and 134 images in '/content/100-bird-species/train/ANDEAN GOOSE'.
# There are 0 directories and 158 images in '/content/100-bird-species/train/BARN OWL'.
# There are 0 directories and 140 images in '/content/100-bird-species/train/NORTHERN MOCKINGBIRD'.
# There are 0 directories and 179 images in '/content/100-bird-species/train/AMERICAN AVOCET'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/WATTLED CURASSOW'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/BLACK SWAN'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/ORIENTAL BAY OWL'.
# There are 0 directories and 213 images in '/content/100-bird-species/train/CASPIAN TERN'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/AFRICAN CROWNED CRANE'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/ANDEAN LAPWING'.
# There are 0 directories and 172 images in '/content/100-bird-species/train/BLACK BREASTED PUFFBIRD'.
# There are 0 directories and 169 images in '/content/100-bird-species/train/SATYR TRAGOPAN'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/LAZULI BUNTING'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/YELLOW CACIQUE'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/BRANDT CORMARANT'.
# There are 0 directories and 158 images in '/content/100-bird-species/train/GREY PLOVER'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/WHITE CHEEKED TURACO'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/BANANAQUIT'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/CRESTED SHRIKETIT'.
# There are 0 directories and 130 images in '/content/100-bird-species/train/RED TAILED THRUSH'.
# There are 0 directories and 142 images in '/content/100-bird-species/train/BLACK AND YELLOW BROADBILL'.
# There are 0 directories and 140 images in '/content/100-bird-species/train/RAINBOW LORIKEET'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/INDIAN VULTURE'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/CANARY'.
# There are 0 directories and 179 images in '/content/100-bird-species/train/AMERICAN PIPIT'.
# There are 0 directories and 166 images in '/content/100-bird-species/train/DOUBLE EYED FIG PARROT'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/TRICOLORED BLACKBIRD'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/BANDED STILT'.
# There are 0 directories and 185 images in '/content/100-bird-species/train/DOUBLE BRESTED CORMARANT'.
# There are 0 directories and 141 images in '/content/100-bird-species/train/COMMON STARLING'.
# There are 0 directories and 187 images in '/content/100-bird-species/train/AFRICAN PIED HORNBILL'.
# There are 0 directories and 130 images in '/content/100-bird-species/train/PATAGONIAN SIERRA FINCH'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/CINNAMON ATTILA'.
# There are 0 directories and 190 images in '/content/100-bird-species/train/LOGGERHEAD SHRIKE'.
# There are 0 directories and 209 images in '/content/100-bird-species/train/PYRRHULOXIA'.
# There are 0 directories and 147 images in '/content/100-bird-species/train/AMERICAN ROBIN'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/GOULDIAN FINCH'.
# There are 0 directories and 186 images in '/content/100-bird-species/train/INDIAN PITTA'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/RING-NECKED PHEASANT'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/KAKAPO'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/TEAL DUCK'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/HOUSE SPARROW'.
# There are 0 directories and 208 images in '/content/100-bird-species/train/ORNATE HAWK EAGLE'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/AFRICAN EMERALD CUCKOO'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/TRUMPTER SWAN'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/CRESTED KINGFISHER'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/SMITHS LONGSPUR'.
# There are 0 directories and 186 images in '/content/100-bird-species/train/BLUE MALKOHA'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/SCARLET IBIS'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/JOCOTOCO ANTPITTA'.
# There are 0 directories and 193 images in '/content/100-bird-species/train/WRENTIT'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/STRIPPED MANAKIN'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/GURNEYS PITTA'.
# There are 0 directories and 174 images in '/content/100-bird-species/train/ROSE BREASTED GROSBEAK'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/AUSTRAL CANASTERO'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/CREAM COLORED WOODPECKER'.
# There are 0 directories and 142 images in '/content/100-bird-species/train/MAGPIE GOOSE'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/VERMILION FLYCATHER'.
# There are 0 directories and 201 images in '/content/100-bird-species/train/VIOLET BACKED STARLING'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/CROW'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/WHITE BREASTED WATERHEN'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/VENEZUELIAN TROUPIAL'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/CERULEAN WARBLER'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/WILD TURKEY'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/BORNEAN PHEASANT'.
# There are 0 directories and 130 images in '/content/100-bird-species/train/AMETHYST WOODSTAR'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/GRAY KINGBIRD'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/CRANE HAWK'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/BROWN THRASHER'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/VISAYAN HORNBILL'.
# There are 0 directories and 134 images in '/content/100-bird-species/train/BLACKBURNIAM WARBLER'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/BALTIMORE ORIOLE'.
# There are 0 directories and 192 images in '/content/100-bird-species/train/BROWN HEADED COWBIRD'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/ABBOTTS BABBLER'.
# There are 0 directories and 185 images in '/content/100-bird-species/train/BLUE GROUSE'.
# There are 0 directories and 151 images in '/content/100-bird-species/train/BIRD OF PARADISE'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/NORTHERN JACANA'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/PURPLE FINCH'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/ANHINGA'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/BLACK-NECKED GREBE'.
# There are 0 directories and 208 images in '/content/100-bird-species/train/MILITARY MACAW'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/SCARLET TANAGER'.
# There are 0 directories and 198 images in '/content/100-bird-species/train/CRIMSON SUNBIRD'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/ECUADORIAN HILLSTAR'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/FAIRY BLUEBIRD'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/SNOWY EGRET'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/RED NAPED TROGON'.
# There are 0 directories and 149 images in '/content/100-bird-species/train/HORNED SUNGEM'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/MASKED BOOBY'.
# There are 0 directories and 143 images in '/content/100-bird-species/train/KOOKABURRA'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/EASTERN TOWEE'.
# There are 0 directories and 173 images in '/content/100-bird-species/train/PYGMY KINGFISHER'.
# There are 0 directories and 193 images in '/content/100-bird-species/train/VARIED THRUSH'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/HOOPOES'.
# There are 0 directories and 140 images in '/content/100-bird-species/train/GOLDEN BOWER BIRD'.
# There are 0 directories and 203 images in '/content/100-bird-species/train/DARK EYED JUNCO'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/CHIPPING SPARROW'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/ROCK DOVE'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/LARK BUNTING'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/LOONEY BIRDS'.
# There are 0 directories and 151 images in '/content/100-bird-species/train/HIMALAYAN MONAL'.
# There are 0 directories and 204 images in '/content/100-bird-species/train/JACOBIN PIGEON'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/TAKAHE'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/KING VULTURE'.
# There are 0 directories and 166 images in '/content/100-bird-species/train/EURASIAN BULLFINCH'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/NICOBAR PIGEON'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/TURKEY VULTURE'.
# There are 0 directories and 131 images in '/content/100-bird-species/train/INDIAN BUSTARD'.
# There are 0 directories and 207 images in '/content/100-bird-species/train/OYSTER CATCHER'.
# There are 0 directories and 131 images in '/content/100-bird-species/train/BLACK FRANCOLIN'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/PALILA'.
# There are 0 directories and 133 images in '/content/100-bird-species/train/RED HEADED WOODPECKER'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/BULWERS PHEASANT'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/BAND TAILED GUAN'.
# There are 0 directories and 189 images in '/content/100-bird-species/train/GREAT ARGUS'.
# There are 0 directories and 185 images in '/content/100-bird-species/train/NORTHERN BEARDLESS TYRANNULET'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/COMMON HOUSE MARTIN'.
# There are 0 directories and 170 images in '/content/100-bird-species/train/AMERICAN BITTERN'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/NORTHERN FLICKER'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/MANGROVE CUCKOO'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/NORTHERN GOSHAWK'.
# There are 0 directories and 151 images in '/content/100-bird-species/train/HARLEQUIN DUCK'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/FAIRY PENGUIN'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/GOLDEN PARAKEET'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/SHORT BILLED DOWITCHER'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/APOSTLEBIRD'.
# There are 0 directories and 184 images in '/content/100-bird-species/train/GREATOR SAGE GROUSE'.
# There are 0 directories and 201 images in '/content/100-bird-species/train/VIOLET GREEN SWALLOW'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/GREATER PEWEE'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/GILDED FLICKER'.
# There are 0 directories and 143 images in '/content/100-bird-species/train/JABIRU'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/AFRICAN OYSTER CATCHER'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/AZURE TANAGER'.
# There are 0 directories and 143 images in '/content/100-bird-species/train/BURCHELLS COURSER'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/VIOLET CUCKOO'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/MALLARD DUCK'.
# There are 0 directories and 167 images in '/content/100-bird-species/train/RED FODY'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/FAIRY TERN'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/BOBOLINK'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/ANIANIAU'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/SUPERB STARLING'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/BLACK SKIMMER'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/FAN TAILED WIDOW'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/DALMATIAN PELICAN'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/EASTERN ROSELLA'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/BORNEAN LEAFBIRD'.
# There are 0 directories and 134 images in '/content/100-bird-species/train/HARLEQUIN QUAIL'.
# There are 0 directories and 143 images in '/content/100-bird-species/train/STRIPED OWL'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/GUINEA TURACO'.
# There are 0 directories and 130 images in '/content/100-bird-species/train/NORTHERN RED BISHOP'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/HAWAIIAN GOOSE'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/CARMINE BEE-EATER'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/RED HEADED DUCK'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/AMERICAN REDSTART'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/TROPICAL KINGBIRD'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/CAPE ROCK THRUSH'.
# There are 0 directories and 193 images in '/content/100-bird-species/train/AMERICAN DIPPER'.
# There are 0 directories and 194 images in '/content/100-bird-species/train/WOODLAND KINGFISHER'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/CHINESE POND HERON'.
# There are 0 directories and 168 images in '/content/100-bird-species/train/LUCIFER HUMMINGBIRD'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/EASTERN WIP POOR WILL'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/MIKADO  PHEASANT'.
# There are 0 directories and 194 images in '/content/100-bird-species/train/BANDED BROADBILL'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/WHITE BROWED CRAKE'.
# There are 0 directories and 148 images in '/content/100-bird-species/train/DOUBLE BARRED FINCH'.
# There are 0 directories and 167 images in '/content/100-bird-species/train/CHUKAR PARTRIDGE'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/GYRFALCON'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/EMERALD TANAGER'.
# There are 0 directories and 206 images in '/content/100-bird-species/train/LAUGHING GULL'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/BLACK TAIL CRAKE'.
# There are 0 directories and 220 images in '/content/100-bird-species/train/ASIAN GREEN BEE EATER'.
# There are 0 directories and 192 images in '/content/100-bird-species/train/ORANGE BREASTED TROGON'.
# There are 0 directories and 200 images in '/content/100-bird-species/train/PLUSH CRESTED JAY'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/INLAND DOTTEREL'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/BARN SWALLOW'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/PURPLE SWAMPHEN'.
# There are 0 directories and 130 images in '/content/100-bird-species/train/EURASIAN GOLDEN ORIOLE'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/KAGU'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/MALABAR HORNBILL'.
# There are 0 directories and 187 images in '/content/100-bird-species/train/MCKAYS BUNTING'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/FIORDLAND PENGUIN'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/TAIWAN MAGPIE'.
# There are 0 directories and 167 images in '/content/100-bird-species/train/RED FACED WARBLER'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/REGENT BOWERBIRD'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/NORTHERN FULMAR'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/INDIGO BUNTING'.
# There are 0 directories and 130 images in '/content/100-bird-species/train/SNOWY PLOVER'.
# There are 0 directories and 190 images in '/content/100-bird-species/train/ASIAN OPENBILL STORK'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/SPANGLED COTINGA'.
# There are 0 directories and 190 images in '/content/100-bird-species/train/DUNLIN'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/IVORY GULL'.
# There are 0 directories and 185 images in '/content/100-bird-species/train/PUNA TEAL'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/AFRICAN FIREFINCH'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/WHITE THROATED BEE EATER'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/BLACK FACED SPOONBILL'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/SPLENDID WREN'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/HORNED GUAN'.
# There are 0 directories and 176 images in '/content/100-bird-species/train/GREEN MAGPIE'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/RED WINGED BLACKBIRD'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/COCK OF THE  ROCK'.
# There are 0 directories and 140 images in '/content/100-bird-species/train/DUSKY ROBIN'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/DARJEELING WOODPECKER'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/EGYPTIAN GOOSE'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/ORANGE BRESTED BUNTING'.
# There are 0 directories and 197 images in '/content/100-bird-species/train/MARABOU STORK'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/SPOTTED CATBIRD'.
# There are 0 directories and 198 images in '/content/100-bird-species/train/BLUE THROATED PIPING GUAN'.
# There are 0 directories and 193 images in '/content/100-bird-species/train/ROSEATE SPOONBILL'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/TURQUOISE MOTMOT'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/KILLDEAR'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/BALI STARLING'.
# There are 0 directories and 142 images in '/content/100-bird-species/train/WATTLED LAPWING'.
# There are 0 directories and 172 images in '/content/100-bird-species/train/WALL CREAPER'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/DUSKY LORY'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/BLUE THROATED TOUCANET'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/STRIPPED SWALLOW'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/EARED PITA'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/LITTLE AUK'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/IWI'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/KIWI'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/RUBY THROATED HUMMINGBIRD'.
# There are 0 directories and 214 images in '/content/100-bird-species/train/WOOD DUCK'.
# There are 0 directories and 140 images in '/content/100-bird-species/train/POMARINE JAEGER'.
# There are 0 directories and 182 images in '/content/100-bird-species/train/CLARKS GREBE'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/JANDAYA PARAKEET'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/PEACOCK'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/BUSH TURKEY'.
# There are 0 directories and 146 images in '/content/100-bird-species/train/DAURIAN REDSTART'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/ALTAMIRA YELLOWTHROAT'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/SANDHILL CRANE'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/GUINEAFOWL'.
# There are 0 directories and 205 images in '/content/100-bird-species/train/EASTERN YELLOW ROBIN'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/SQUACCO HERON'.
# There are 0 directories and 143 images in '/content/100-bird-species/train/BAY-BREASTED WARBLER'.
# There are 0 directories and 170 images in '/content/100-bird-species/train/CHESTNUT WINGED CUCKOO'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/IMPERIAL SHAQ'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/YELLOW BELLIED FLOWERPECKER'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/BLOOD PHEASANT'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/COMMON FIRECREST'.
# There are 0 directories and 133 images in '/content/100-bird-species/train/CAPE LONGCLAW'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/FASCIATED WREN'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/ASIAN CRESTED IBIS'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/BROWN NOODY'.
# There are 0 directories and 141 images in '/content/100-bird-species/train/TAILORBIRD'.
# There are 0 directories and 179 images in '/content/100-bird-species/train/AFRICAN PYGMY GOOSE'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/CRESTED CARACARA'.
# There are 0 directories and 133 images in '/content/100-bird-species/train/BLACK-CAPPED CHICKADEE'.
# There are 0 directories and 179 images in '/content/100-bird-species/train/ABYSSINIAN GROUND HORNBILL'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/GREAT GRAY OWL'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/EUROPEAN GOLDFINCH'.
# There are 0 directories and 180 images in '/content/100-bird-species/train/CEDAR WAXWING'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/RED FACED CORMORANT'.
# There are 0 directories and 233 images in '/content/100-bird-species/train/OVENBIRD'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/GOLDEN PHEASANT'.
# There are 0 directories and 190 images in '/content/100-bird-species/train/VEERY'.
# There are 0 directories and 182 images in '/content/100-bird-species/train/VERDIN'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/DEMOISELLE CRANE'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/HYACINTH MACAW'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/BALD IBIS'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/COMMON LOON'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/HOATZIN'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/INDIGO FLYCATCHER'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/HEPATIC TANAGER'.
# There are 0 directories and 181 images in '/content/100-bird-species/train/CRESTED SERPENT EAGLE'.
# There are 0 directories and 145 images in '/content/100-bird-species/train/BLACK THROATED HUET'.
# There are 0 directories and 143 images in '/content/100-bird-species/train/MALAGASY WHITE EYE'.
# There are 0 directories and 141 images in '/content/100-bird-species/train/IBISBILL'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/MANDRIN DUCK'.
# There are 0 directories and 193 images in '/content/100-bird-species/train/RAZORBILL'.
# There are 0 directories and 197 images in '/content/100-bird-species/train/SAYS PHOEBE'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/FRIGATE'.
# There are 0 directories and 158 images in '/content/100-bird-species/train/AMERICAN COOT'.
# There are 0 directories and 158 images in '/content/100-bird-species/train/GOLDEN PIPIT'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/SHOEBILL'.
# There are 0 directories and 142 images in '/content/100-bird-species/train/BEARDED BELLBIRD'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/CUBAN TROGON'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/COMMON POORWILL'.
# There are 0 directories and 197 images in '/content/100-bird-species/train/RED BEARDED BEE EATER'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/HAMERKOP'.
# There are 0 directories and 134 images in '/content/100-bird-species/train/EASTERN BLUEBONNET'.
# There are 0 directories and 177 images in '/content/100-bird-species/train/BROWN CREPPER'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/ROSY FACED LOVEBIRD'.
# There are 0 directories and 187 images in '/content/100-bird-species/train/AUCKLAND SHAQ'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/WHITE NECKED RAVEN'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/COPPERY TAILED COUCAL'.
# There are 0 directories and 192 images in '/content/100-bird-species/train/PALM NUT VULTURE'.
# There are 0 directories and 190 images in '/content/100-bird-species/train/EASTERN MEADOWLARK'.
# There are 0 directories and 142 images in '/content/100-bird-species/train/ROYAL FLYCATCHER'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/BEARDED REEDLING'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/AMERICAN KESTREL'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/BEARDED BARBET'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/BLUE COAU'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/SCARLET CROWNED FRUIT DOVE'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/CURL CRESTED ARACURI'.
# There are 0 directories and 216 images in '/content/100-bird-species/train/SWINHOES PHEASANT'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/SCARLET FACED LIOCICHLA'.
# There are 0 directories and 158 images in '/content/100-bird-species/train/JAPANESE ROBIN'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/CACTUS WREN'.
# There are 0 directories and 203 images in '/content/100-bird-species/train/GREATER PRAIRIE CHICKEN'.
# There are 0 directories and 169 images in '/content/100-bird-species/train/SUNBITTERN'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/MALEO'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/GOLD WING WARBLER'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/GRANDALA'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/WHITE TAILED TROPIC'.
# There are 0 directories and 172 images in '/content/100-bird-species/train/FOREST WAGTAIL'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/GILA WOODPECKER'.
# There are 0 directories and 197 images in '/content/100-bird-species/train/CAMPO FLICKER'.
# There are 0 directories and 173 images in '/content/100-bird-species/train/BLUE DACNIS'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/ELEGANT TROGON'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/IBERIAN MAGPIE'.
# There are 0 directories and 141 images in '/content/100-bird-species/train/AZURE BREASTED PITTA'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/CHARA DE COLLAR'.
# There are 0 directories and 177 images in '/content/100-bird-species/train/CABOTS TRAGOPAN'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/RED BROWED FINCH'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/ELLIOTS  PHEASANT'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/UMBRELLA BIRD'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/CLARKS NUTCRACKER'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/ANTBIRD'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/GREEN JAY'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/SCARLET MACAW'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/ANTILLEAN EUPHONIA'.
# There are 0 directories and 197 images in '/content/100-bird-species/train/KNOB BILLED DUCK'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/NORTHERN GANNET'.
# There are 0 directories and 209 images in '/content/100-bird-species/train/FRILL BACK PIGEON'.
# There are 0 directories and 137 images in '/content/100-bird-species/train/CHATTERING LORY'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/CRIMSON CHAT'.
# There are 0 directories and 176 images in '/content/100-bird-species/train/PARADISE TANAGER'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/CRESTED OROPENDOLA'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/ARARIPE MANAKIN'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/OCELLATED TURKEY'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/NOISY FRIARBIRD'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/AMERICAN FLAMINGO'.
# There are 0 directories and 176 images in '/content/100-bird-species/train/WHITE EARED HUMMINGBIRD'.
# There are 0 directories and 181 images in '/content/100-bird-species/train/BLACK HEADED CAIQUE'.
# There are 0 directories and 212 images in '/content/100-bird-species/train/RED BILLED TROPICBIRD'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/CAATINGA CACHOLOTE'.
# There are 0 directories and 142 images in '/content/100-bird-species/train/CRESTED FIREBACK'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/STORK BILLED KINGFISHER'.
# There are 0 directories and 190 images in '/content/100-bird-species/train/SNOW GOOSE'.
# There are 0 directories and 176 images in '/content/100-bird-species/train/GOLDEN CHEEKED WARBLER'.
# There are 0 directories and 170 images in '/content/100-bird-species/train/KING EIDER'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/CALIFORNIA GULL'.
# There are 0 directories and 248 images in '/content/100-bird-species/train/HOUSE FINCH'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/LESSER ADJUTANT'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/SNOWY OWL'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/GREY CUCKOOSHRIKE'.
# There are 0 directories and 183 images in '/content/100-bird-species/train/INDIAN ROLLER'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/BLACK COCKATO'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/ENGGANO MYNA'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/JAVA SPARROW'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/EUROPEAN TURTLE DOVE'.
# There are 0 directories and 144 images in '/content/100-bird-species/train/CRAB PLOVER'.
# There are 0 directories and 196 images in '/content/100-bird-species/train/NORTHERN PARULA'.
# There are 0 directories and 149 images in '/content/100-bird-species/train/GREAT XENOPS'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/VIOLET TURACO'.
# There are 0 directories and 169 images in '/content/100-bird-species/train/VULTURINE GUINEAFOWL'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/BALD EAGLE'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/PARAKETT  AUKLET'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/CASSOWARY'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/GREEN WINGED DOVE'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/EASTERN GOLDEN WEAVER'.
# There are 0 directories and 168 images in '/content/100-bird-species/train/AZARAS SPINETAIL'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/GLOSSY IBIS'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/QUETZAL'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/CAPE GLOSSY STARLING'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/CHINESE BAMBOO PARTRIDGE'.
# There are 0 directories and 170 images in '/content/100-bird-species/train/BLUE GROSBEAK'.
# There are 0 directories and 131 images in '/content/100-bird-species/train/MASKED LAPWING'.
# There are 0 directories and 197 images in '/content/100-bird-species/train/CRESTED WOOD PARTRIDGE'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/PEREGRINE FALCON'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/PAINTED BUNTING'.
# There are 0 directories and 172 images in '/content/100-bird-species/train/COLLARED CRESCENTCHEST'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/JACK SNIPE'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/WILSONS BIRD OF PARADISE'.
# There are 0 directories and 196 images in '/content/100-bird-species/train/COPPERSMITH BARBET'.
# There are 0 directories and 141 images in '/content/100-bird-species/train/ASIAN DOLLARD BIRD'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/GREAT TINAMOU'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/CRESTED COUA'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/HOODED MERGANSER'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/SRI LANKA BLUE MAGPIE'.
# There are 0 directories and 177 images in '/content/100-bird-species/train/FLAME TANAGER'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/CRESTED NUTHATCH'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/EMU'.
# There are 0 directories and 177 images in '/content/100-bird-species/train/COMMON GRACKLE'.
# There are 0 directories and 166 images in '/content/100-bird-species/train/ALPINE CHOUGH'.
# There are 0 directories and 158 images in '/content/100-bird-species/train/GOLDEN EAGLE'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/PHILIPPINE EAGLE'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/ANDEAN SISKIN'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/BAIKAL TEAL'.
# There are 0 directories and 159 images in '/content/100-bird-species/train/YELLOW HEADED BLACKBIRD'.
# There are 0 directories and 132 images in '/content/100-bird-species/train/BARROWS GOLDENEYE'.
# There are 0 directories and 168 images in '/content/100-bird-species/train/BAR-TAILED GODWIT'.
# There are 0 directories and 195 images in '/content/100-bird-species/train/BLUE GRAY GNATCATCHER'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/MALACHITE KINGFISHER'.
# There are 0 directories and 166 images in '/content/100-bird-species/train/COCKATOO'.
# There are 0 directories and 138 images in '/content/100-bird-species/train/WHIMBREL'.
# There are 0 directories and 155 images in '/content/100-bird-species/train/GRAY CATBIRD'.
# There are 0 directories and 139 images in '/content/100-bird-species/train/ANNAS HUMMINGBIRD'.
# There are 0 directories and 133 images in '/content/100-bird-species/train/COMMON IORA'.
# There are 0 directories and 180 images in '/content/100-bird-species/train/ABBOTTS BOOBY'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/BORNEAN BRISTLEHEAD'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/ROUGH LEG BUZZARD'.
# There are 0 directories and 187 images in '/content/100-bird-species/train/AMERICAN WIGEON'.
# There are 0 directories and 187 images in '/content/100-bird-species/train/SNOWY SHEATHBILL'.
# There are 0 directories and 140 images in '/content/100-bird-species/train/GREEN BROADBILL'.
# There are 0 directories and 152 images in '/content/100-bird-species/train/CALIFORNIA CONDOR'.
# There are 0 directories and 185 images in '/content/100-bird-species/train/CANVASBACK'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/CINNAMON FLYCATCHER'.
# There are 0 directories and 131 images in '/content/100-bird-species/train/GO AWAY BIRD'.
# There are 0 directories and 133 images in '/content/100-bird-species/train/AMERICAN GOLDFINCH'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/OSTRICH'.
# There are 0 directories and 200 images in '/content/100-bird-species/train/LIMPKIN'.
# There are 0 directories and 167 images in '/content/100-bird-species/train/HAWFINCH'.
# There are 0 directories and 162 images in '/content/100-bird-species/train/CUBAN TODY'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/EASTERN BLUEBIRD'.
# There are 0 directories and 188 images in '/content/100-bird-species/train/ASHY STORM PETREL'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/STEAMER DUCK'.
# There are 0 directories and 177 images in '/content/100-bird-species/train/COLLARED ARACARI'.
# There are 0 directories and 167 images in '/content/100-bird-species/train/BLUE HERON'.
# There are 0 directories and 141 images in '/content/100-bird-species/train/CHUCAO TAPACULO'.
# There are 0 directories and 153 images in '/content/100-bird-species/train/NORTHERN SHOVELER'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/AZURE TIT'.
# There are 0 directories and 163 images in '/content/100-bird-species/train/GREAT JACAMAR'.
# There are 0 directories and 202 images in '/content/100-bird-species/train/YELLOW BREASTED CHAT'.
# There are 0 directories and 157 images in '/content/100-bird-species/train/DOWNY WOODPECKER'.
# There are 0 directories and 156 images in '/content/100-bird-species/train/BLACK BAZA'.
# There are 0 directories and 161 images in '/content/100-bird-species/train/CALIFORNIA QUAIL'.
# There are 0 directories and 169 images in '/content/100-bird-species/train/RED LEGGED HONEYCREEPER'.
# There are 0 directories and 185 images in '/content/100-bird-species/train/SURF SCOTER'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/LONG-EARED OWL'.
# There are 0 directories and 200 images in '/content/100-bird-species/train/SORA'.
# There are 0 directories and 175 images in '/content/100-bird-species/train/HARPY EAGLE'.
# There are 0 directories and 154 images in '/content/100-bird-species/train/EURASIAN MAGPIE'.
# There are 0 directories and 197 images in '/content/100-bird-species/train/ROSE BREASTED COCKATOO'.
# There are 0 directories and 170 images in '/content/100-bird-species/train/ZEBRA DOVE'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/AZURE JAY'.
# There are 0 directories and 164 images in '/content/100-bird-species/train/ASHY THRUSHBIRD'.
# There are 0 directories and 149 images in '/content/100-bird-species/train/IVORY BILLED ARACARI'.
# There are 0 directories and 135 images in '/content/100-bird-species/train/GOLDEN CHLOROPHONIA'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/FIERY MINIVET'.
# There are 0 directories and 150 images in '/content/100-bird-species/train/HIMALAYAN BLUETAIL'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/TOUCHAN'.
# There are 0 directories and 165 images in '/content/100-bird-species/train/ALEXANDRINE PARAKEET'.
# There are 0 directories and 136 images in '/content/100-bird-species/train/BARRED PUFFBIRD'.
# There are 0 directories and 160 images in '/content/100-bird-species/train/GRAY PARTRIDGE'.

# %%
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.png'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
sample_df = image_df.sample(10500)

# %%
os.listdir(dataset)
# Out:
# ['MASKED BOBWHITE',
#  'TOWNSENDS WARBLER',
#  'TIT MOUSE',
#  'GREAT POTOO',
#  'RED TAILED HAWK',
#  'INCA TERN',
#  'RED KNOT',
#  'TREE SWALLOW',
#  'WOOD THRUSH',
#  'TAWNY FROGMOUTH',
#  'GREY HEADED CHACHALACA',
#  'RUBY CROWNED KINGLET',
#  'BLACK VENTED SHEARWATER',
#  'STRIATED CARACARA',
#  'OSPREY',
#  'NORTHERN CARDINAL',
#  'CAPPED HERON',
#  'WILLOW PTARMIGAN',
#  'WHITE CRESTED HORNBILL',
#  'CINNAMON TEAL',
#  'SNOW PARTRIDGE',
#  'MYNA',
#  'BUFFLEHEAD',
#  'FLAME BOWERBIRD',
#  'RUDDY SHELDUCK',
#  'PURPLE GALLINULE',
#  'PURPLE MARTIN',
#  'BANDED PITA',
#  'GAMBELS QUAIL',
#  'SAND MARTIN',
#  'BLACK THROATED WARBLER',
#  'ROADRUNNER',
#  'OILBIRD',
#  'AUSTRALASIAN FIGBIRD',
#  'SPOTTED WHISTLING DUCK',
#  'PUFFIN',
#  'RED SHOULDERED HAWK',
#  'RED CROSSBILL',
#  'BLACK VULTURE',
#  'MOURNING DOVE',
#  'APAPANE',
#  'SAMATRAN THRUSH',
#  'GROVED BILLED ANI',
#  'PHAINOPEPLA',
#  'RED BELLIED PITTA',
#  'CAPE MAY WARBLER',
#  'VICTORIA CROWNED PIGEON',
#  'HELMET VANGA',
#  'EMPEROR PENGUIN',
#  'TASMANIAN HEN',
#  'CAPUCHINBIRD',
#  'GANG GANG COCKATOO',
#  'BELTED KINGFISHER',
#  'MERLIN',
#  'EVENING GROSBEAK',
#  'RUFUOS MOTMOT',
#  'SPOON BILED SANDPIPER',
#  'BLACK-THROATED SPARROW',
#  'FIRE TAILLED MYZORNIS',
#  'AVADAVAT',
#  'BREWERS BLACKBIRD',
#  'HORNED LARK',
#  'GREAT KISKADEE',
#  'ALBATROSS',
#  'PINK ROBIN',
#  'RUFOUS TREPE',
#  'CRESTED AUKLET',
#  'ALBERTS TOWHEE',
#  'BLACK THROATED BUSHTIT',
#  'RUFOUS KINGFISHER',
#  'PARUS MAJOR',
#  'D-ARNAUDS BARBET',
#  'GREY HEADED FISH EAGLE',
#  'LILAC ROLLER',
#  'BLONDE CRESTED WOODPECKER',
#  'CHESTNET BELLIED EUPHONIA',
#  'RUDY KINGFISHER',
#  'OKINAWA RAIL',
#  'RED WISKERED BULBUL',
#  'BLACK NECKED STILT',
#  'ANDEAN GOOSE',
#  'BARN OWL',
#  'NORTHERN MOCKINGBIRD',
#  'AMERICAN AVOCET',
#  'WATTLED CURASSOW',
#  'BLACK SWAN',
#  'ORIENTAL BAY OWL',
#  'CASPIAN TERN',
#  'AFRICAN CROWNED CRANE',
#  'ANDEAN LAPWING',
#  'BLACK BREASTED PUFFBIRD',
#  'SATYR TRAGOPAN',
#  'LAZULI BUNTING',
#  'YELLOW CACIQUE',
#  'BRANDT CORMARANT',
#  'GREY PLOVER',
#  'WHITE CHEEKED TURACO',
#  'BANANAQUIT',
#  'CRESTED SHRIKETIT',
#  'RED TAILED THRUSH',
#  'BLACK AND YELLOW BROADBILL',
#  'RAINBOW LORIKEET',
#  'INDIAN VULTURE',
#  'CANARY',
#  'AMERICAN PIPIT',
#  'DOUBLE EYED FIG PARROT',
#  'TRICOLORED BLACKBIRD',
#  'BANDED STILT',
#  'DOUBLE BRESTED CORMARANT',
#  'COMMON STARLING',
#  'AFRICAN PIED HORNBILL',
#  'PATAGONIAN SIERRA FINCH',
#  'CINNAMON ATTILA',
#  'LOGGERHEAD SHRIKE',
#  'PYRRHULOXIA',
#  'AMERICAN ROBIN',
#  'GOULDIAN FINCH',
#  'INDIAN PITTA',
#  'RING-NECKED PHEASANT',
#  'KAKAPO',
#  'TEAL DUCK',
#  'HOUSE SPARROW',
#  'ORNATE HAWK EAGLE',
#  'AFRICAN EMERALD CUCKOO',
#  'TRUMPTER SWAN',
#  'CRESTED KINGFISHER',
#  'SMITHS LONGSPUR',
#  'BLUE MALKOHA',
#  'SCARLET IBIS',
#  'JOCOTOCO ANTPITTA',
#  'WRENTIT',
#  'STRIPPED MANAKIN',
#  'GURNEYS PITTA',
#  'ROSE BREASTED GROSBEAK',
#  'AUSTRAL CANASTERO',
#  'CREAM COLORED WOODPECKER',
#  'MAGPIE GOOSE',
#  'VERMILION FLYCATHER',
#  'VIOLET BACKED STARLING',
#  'CROW',
#  'WHITE BREASTED WATERHEN',
#  'VENEZUELIAN TROUPIAL',
#  'CERULEAN WARBLER',
#  'WILD TURKEY',
#  'BORNEAN PHEASANT',
#  'AMETHYST WOODSTAR',
#  'GRAY KINGBIRD',
#  'CRANE HAWK',
#  'BROWN THRASHER',
#  'VISAYAN HORNBILL',
#  'BLACKBURNIAM WARBLER',
#  'BALTIMORE ORIOLE',
#  'BROWN HEADED COWBIRD',
#  'ABBOTTS BABBLER',
#  'BLUE GROUSE',
#  'BIRD OF PARADISE',
#  'NORTHERN JACANA',
#  'PURPLE FINCH',
#  'ANHINGA',
#  'BLACK-NECKED GREBE',
#  'MILITARY MACAW',
#  'SCARLET TANAGER',
#  'CRIMSON SUNBIRD',
#  'ECUADORIAN HILLSTAR',
#  'FAIRY BLUEBIRD',
#  'SNOWY EGRET',
#  'RED NAPED TROGON',
#  'HORNED SUNGEM',
#  'MASKED BOOBY',
#  'KOOKABURRA',
#  'EASTERN TOWEE',
#  'PYGMY KINGFISHER',
#  'VARIED THRUSH',
#  'HOOPOES',
#  'GOLDEN BOWER BIRD',
#  'DARK EYED JUNCO',
#  'CHIPPING SPARROW',
#  'ROCK DOVE',
#  'LARK BUNTING',
#  'LOONEY BIRDS',
#  'HIMALAYAN MONAL',
#  'JACOBIN PIGEON',
#  'TAKAHE',
#  'KING VULTURE',
#  'EURASIAN BULLFINCH',
#  'NICOBAR PIGEON',
#  'TURKEY VULTURE',
#  'INDIAN BUSTARD',
#  'OYSTER CATCHER',
#  'BLACK FRANCOLIN',
#  'PALILA',
#  'RED HEADED WOODPECKER',
#  'BULWERS PHEASANT',
#  'BAND TAILED GUAN',
#  'GREAT ARGUS',
#  'NORTHERN BEARDLESS TYRANNULET',
#  'COMMON HOUSE MARTIN',
#  'AMERICAN BITTERN',
#  'NORTHERN FLICKER',
#  'MANGROVE CUCKOO',
#  'NORTHERN GOSHAWK',
#  'HARLEQUIN DUCK',
#  'FAIRY PENGUIN',
#  'GOLDEN PARAKEET',
#  'SHORT BILLED DOWITCHER',
#  'APOSTLEBIRD',
#  'GREATOR SAGE GROUSE',
#  'VIOLET GREEN SWALLOW',
#  'GREATER PEWEE',
#  'GILDED FLICKER',
#  'JABIRU',
#  'AFRICAN OYSTER CATCHER',
#  'AZURE TANAGER',
#  'BURCHELLS COURSER',
#  'VIOLET CUCKOO',
#  'MALLARD DUCK',
#  'RED FODY',
#  'FAIRY TERN',
#  'BOBOLINK',
#  'ANIANIAU',
#  'SUPERB STARLING',
#  'BLACK SKIMMER',
#  'FAN TAILED WIDOW',
#  'DALMATIAN PELICAN',
#  'EASTERN ROSELLA',
#  'BORNEAN LEAFBIRD',
#  'HARLEQUIN QUAIL',
#  'STRIPED OWL',
#  'GUINEA TURACO',
#  'NORTHERN RED BISHOP',
#  'HAWAIIAN GOOSE',
#  'CARMINE BEE-EATER',
#  'RED HEADED DUCK',
#  'AMERICAN REDSTART',
#  'TROPICAL KINGBIRD',
#  'CAPE ROCK THRUSH',
#  'AMERICAN DIPPER',
#  'WOODLAND KINGFISHER',
#  'CHINESE POND HERON',
#  'LUCIFER HUMMINGBIRD',
#  'EASTERN WIP POOR WILL',
#  'MIKADO  PHEASANT',
#  'BANDED BROADBILL',
#  'WHITE BROWED CRAKE',
#  'DOUBLE BARRED FINCH',
#  'CHUKAR PARTRIDGE',
#  'GYRFALCON',
#  'EMERALD TANAGER',
#  'LAUGHING GULL',
#  'BLACK TAIL CRAKE',
#  'ASIAN GREEN BEE EATER',
#  'ORANGE BREASTED TROGON',
#  'PLUSH CRESTED JAY',
#  'INLAND DOTTEREL',
#  'BARN SWALLOW',
#  'PURPLE SWAMPHEN',
#  'EURASIAN GOLDEN ORIOLE',
#  'KAGU',
#  'MALABAR HORNBILL',
#  'MCKAYS BUNTING',
#  'FIORDLAND PENGUIN',
#  'TAIWAN MAGPIE',
#  'RED FACED WARBLER',
#  'REGENT BOWERBIRD',
#  'NORTHERN FULMAR',
#  'INDIGO BUNTING',
#  'SNOWY PLOVER',
#  'ASIAN OPENBILL STORK',
#  'SPANGLED COTINGA',
#  'DUNLIN',
#  'IVORY GULL',
#  'PUNA TEAL',
#  'AFRICAN FIREFINCH',
#  'WHITE THROATED BEE EATER',
#  'BLACK FACED SPOONBILL',
#  'SPLENDID WREN',
#  'HORNED GUAN',
#  'GREEN MAGPIE',
#  'RED WINGED BLACKBIRD',
#  'COCK OF THE  ROCK',
#  'DUSKY ROBIN',
#  'DARJEELING WOODPECKER',
#  'EGYPTIAN GOOSE',
#  'ORANGE BRESTED BUNTING',
#  'MARABOU STORK',
#  'SPOTTED CATBIRD',
#  'BLUE THROATED PIPING GUAN',
#  'ROSEATE SPOONBILL',
#  'TURQUOISE MOTMOT',
#  'KILLDEAR',
#  'BALI STARLING',
#  'WATTLED LAPWING',
#  'WALL CREAPER',
#  'DUSKY LORY',
#  'BLUE THROATED TOUCANET',
#  'STRIPPED SWALLOW',
#  'EARED PITA',
#  'LITTLE AUK',
#  'IWI',
#  'KIWI',
#  'RUBY THROATED HUMMINGBIRD',
#  'WOOD DUCK',
#  'POMARINE JAEGER',
#  'CLARKS GREBE',
#  'JANDAYA PARAKEET',
#  'PEACOCK',
#  'BUSH TURKEY',
#  'DAURIAN REDSTART',
#  'ALTAMIRA YELLOWTHROAT',
#  'SANDHILL CRANE',
#  'GUINEAFOWL',
#  'EASTERN YELLOW ROBIN',
#  'SQUACCO HERON',
#  'BAY-BREASTED WARBLER',
#  'CHESTNUT WINGED CUCKOO',
#  'IMPERIAL SHAQ',
#  'YELLOW BELLIED FLOWERPECKER',
#  'BLOOD PHEASANT',
#  'COMMON FIRECREST',
#  'CAPE LONGCLAW',
#  'FASCIATED WREN',
#  'ASIAN CRESTED IBIS',
#  'BROWN NOODY',
#  'TAILORBIRD',
#  'AFRICAN PYGMY GOOSE',
#  'CRESTED CARACARA',
#  'BLACK-CAPPED CHICKADEE',
#  'ABYSSINIAN GROUND HORNBILL',
#  'GREAT GRAY OWL',
#  'EUROPEAN GOLDFINCH',
#  'CEDAR WAXWING',
#  'RED FACED CORMORANT',
#  'OVENBIRD',
#  'GOLDEN PHEASANT',
#  'VEERY',
#  'VERDIN',
#  'DEMOISELLE CRANE',
#  'HYACINTH MACAW',
#  'BALD IBIS',
#  'COMMON LOON',
#  'HOATZIN',
#  'INDIGO FLYCATCHER',
#  'HEPATIC TANAGER',
#  'CRESTED SERPENT EAGLE',
#  'BLACK THROATED HUET',
#  'MALAGASY WHITE EYE',
#  'IBISBILL',
#  'MANDRIN DUCK',
#  'RAZORBILL',
#  'SAYS PHOEBE',
#  'FRIGATE',
#  'AMERICAN COOT',
#  'GOLDEN PIPIT',
#  'SHOEBILL',
#  'BEARDED BELLBIRD',
#  'CUBAN TROGON',
#  'COMMON POORWILL',
#  'RED BEARDED BEE EATER',
#  'HAMERKOP',
#  'EASTERN BLUEBONNET',
#  'BROWN CREPPER',
#  'ROSY FACED LOVEBIRD',
#  'AUCKLAND SHAQ',
#  'WHITE NECKED RAVEN',
#  'COPPERY TAILED COUCAL',
#  'PALM NUT VULTURE',
#  'EASTERN MEADOWLARK',
#  'ROYAL FLYCATCHER',
#  'BEARDED REEDLING',
#  'AMERICAN KESTREL',
#  'BEARDED BARBET',
#  'BLUE COAU',
#  'SCARLET CROWNED FRUIT DOVE',
#  'CURL CRESTED ARACURI',
#  'SWINHOES PHEASANT',
#  'SCARLET FACED LIOCICHLA',
#  'JAPANESE ROBIN',
#  'CACTUS WREN',
#  'GREATER PRAIRIE CHICKEN',
#  'SUNBITTERN',
#  'MALEO',
#  'GOLD WING WARBLER',
#  'GRANDALA',
#  'WHITE TAILED TROPIC',
#  'FOREST WAGTAIL',
#  'GILA WOODPECKER',
#  'CAMPO FLICKER',
#  'BLUE DACNIS',
#  'ELEGANT TROGON',
#  'IBERIAN MAGPIE',
#  'AZURE BREASTED PITTA',
#  'CHARA DE COLLAR',
#  'CABOTS TRAGOPAN',
#  'RED BROWED FINCH',
#  'ELLIOTS  PHEASANT',
#  'UMBRELLA BIRD',
#  'CLARKS NUTCRACKER',
#  'ANTBIRD',
#  'GREEN JAY',
#  'SCARLET MACAW',
#  'ANTILLEAN EUPHONIA',
#  'KNOB BILLED DUCK',
#  'NORTHERN GANNET',
#  'FRILL BACK PIGEON',
#  'CHATTERING LORY',
#  'CRIMSON CHAT',
#  'PARADISE TANAGER',
#  'CRESTED OROPENDOLA',
#  'ARARIPE MANAKIN',
#  'OCELLATED TURKEY',
#  'NOISY FRIARBIRD',
#  'AMERICAN FLAMINGO',
#  'WHITE EARED HUMMINGBIRD',
#  'BLACK HEADED CAIQUE',
#  'RED BILLED TROPICBIRD',
#  'CAATINGA CACHOLOTE',
#  'CRESTED FIREBACK',
#  'STORK BILLED KINGFISHER',
#  'SNOW GOOSE',
#  'GOLDEN CHEEKED WARBLER',
#  'KING EIDER',
#  'CALIFORNIA GULL',
#  'HOUSE FINCH',
#  'LESSER ADJUTANT',
#  'SNOWY OWL',
#  'GREY CUCKOOSHRIKE',
#  'INDIAN ROLLER',
#  'BLACK COCKATO',
#  'ENGGANO MYNA',
#  'JAVA SPARROW',
#  'EUROPEAN TURTLE DOVE',
#  'CRAB PLOVER',
#  'NORTHERN PARULA',
#  'GREAT XENOPS',
#  'VIOLET TURACO',
#  'VULTURINE GUINEAFOWL',
#  'BALD EAGLE',
#  'PARAKETT  AUKLET',
#  'CASSOWARY',
#  'GREEN WINGED DOVE',
#  'EASTERN GOLDEN WEAVER',
#  'AZARAS SPINETAIL',
#  'GLOSSY IBIS',
#  'QUETZAL',
#  'CAPE GLOSSY STARLING',
#  'CHINESE BAMBOO PARTRIDGE',
#  'BLUE GROSBEAK',
#  'MASKED LAPWING',
#  'CRESTED WOOD PARTRIDGE',
#  'PEREGRINE FALCON',
#  'PAINTED BUNTING',
#  'COLLARED CRESCENTCHEST',
#  'JACK SNIPE',
#  'WILSONS BIRD OF PARADISE',
#  'COPPERSMITH BARBET',
#  'ASIAN DOLLARD BIRD',
#  'GREAT TINAMOU',
#  'CRESTED COUA',
#  'HOODED MERGANSER',
#  'SRI LANKA BLUE MAGPIE',
#  'FLAME TANAGER',
#  'CRESTED NUTHATCH',
#  'EMU',
#  'COMMON GRACKLE',
#  'ALPINE CHOUGH',
#  'GOLDEN EAGLE',
#  'PHILIPPINE EAGLE',
#  'ANDEAN SISKIN',
#  'BAIKAL TEAL',
#  'YELLOW HEADED BLACKBIRD',
#  'BARROWS GOLDENEYE',
#  'BAR-TAILED GODWIT',
#  'BLUE GRAY GNATCATCHER',
#  'MALACHITE KINGFISHER',
#  'COCKATOO',
#  'WHIMBREL',
#  'GRAY CATBIRD',
#  'ANNAS HUMMINGBIRD',
#  'COMMON IORA',
#  'ABBOTTS BOOBY',
#  'BORNEAN BRISTLEHEAD',
#  'ROUGH LEG BUZZARD',
#  'AMERICAN WIGEON',
#  'SNOWY SHEATHBILL',
#  'GREEN BROADBILL',
#  'CALIFORNIA CONDOR',
#  'CANVASBACK',
#  'CINNAMON FLYCATCHER',
#  'GO AWAY BIRD',
#  'AMERICAN GOLDFINCH',
#  'OSTRICH',
#  'LIMPKIN',
#  'HAWFINCH',
#  'CUBAN TODY',
#  'EASTERN BLUEBIRD',
#  'ASHY STORM PETREL',
#  'STEAMER DUCK',
#  'COLLARED ARACARI',
#  'BLUE HERON',
#  'CHUCAO TAPACULO',
#  'NORTHERN SHOVELER',
#  'AZURE TIT',
#  'GREAT JACAMAR',
#  'YELLOW BREASTED CHAT',
#  'DOWNY WOODPECKER',
#  'BLACK BAZA',
#  'CALIFORNIA QUAIL',
#  'RED LEGGED HONEYCREEPER',
#  'SURF SCOTER',
#  'LONG-EARED OWL',
#  'SORA',
#  'HARPY EAGLE',
#  'EURASIAN MAGPIE',
#  'ROSE BREASTED COCKATOO',
#  'ZEBRA DOVE',
#  'AZURE JAY',
#  'ASHY THRUSHBIRD',
#  'IVORY BILLED ARACARI',
#  'GOLDEN CHLOROPHONIA',
#  'FIERY MINIVET',
#  'HIMALAYAN BLUETAIL',
#  'TOUCHAN',
#  'ALEXANDRINE PARAKEET',
#  'BARRED PUFFBIRD',
#  'GRAY PARTRIDGE']

# %%
# Get the top 20 labels
label_counts = image_df['Label'].value_counts()[:20]

plt.figure(figsize=(20, 6))
sns.barplot(x=label_counts.index, y=label_counts.values, alpha=0.8, palette='dark:salmon_r')
plt.title('Distribution of Top 20 Labels in Image Dataset', fontsize=16)
plt.xlabel('Label', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-11-371b102a4acd>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, alpha=0.8, palette='dark:salmon_r')

# %%
# Display 16 picture of the dataset with their labels
random_index = np.random.randint(0, len(image_df), 16)
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[random_index[i]]))
    ax.set_title(image_df.Label[random_index[i]])
plt.tight_layout()
plt.show()

# %%
def compute_ela_cv(path, quality):
    temp_filename = 'temp_file_name.jpeg'
    SCALE = 15
    orig_img = cv2.imread(path)
    orig_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)

    cv2.imwrite(temp_filename, orig_img, [cv2.IMWRITE_JPEG_QUALITY, quality])

    # read compressed image
    compressed_img = cv2.imread(temp_filename)

    # get absolute difference between img1 and img2 and multiply by scale
    diff = SCALE * cv2.absdiff(orig_img, compressed_img)
    return diff


def convert_to_ela_image(path, quality):
    temp_filename = 'temp_file_name.jpeg'
    ela_filename = 'temp_ela.png'
    image = Image.open(path).convert('RGB')
    image.save(temp_filename, 'JPEG', quality = quality)
    temp_image = Image.open(temp_filename)

    ela_image = ImageChops.difference(image, temp_image)

    extrema = ela_image.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    if max_diff == 0:
        max_diff = 1

    scale = 255.0 / max_diff
    ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)

    return ela_image


def random_sample(path, extension=None):
    if extension:
        items = Path(path).glob(f'*.{extension}')
    else:
        items = Path(path).glob(f'*')

    items = list(items)

    p = random.choice(items)
    return p.as_posix()

# %%
# View random sample from the dataset
p = random_sample('/content/100-bird-species/train/GOLDEN EAGLE')
orig = cv2.imread(p)
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB) / 255.0
init_val = 100
columns = 3
rows = 3

fig=plt.figure(figsize=(15, 10))
for i in range(1, columns*rows +1):
    quality=init_val - (i-1) * 8
    img = compute_ela_cv(path=p, quality=quality)
    if i == 1:
        img = orig.copy()
    ax = fig.add_subplot(rows, columns, i)
    ax.title.set_text(f'q: {quality}')
    plt.imshow(img)
plt.show()

# %%
# Separate in train and test data
train_df, test_df = train_test_split(sample_df, test_size=0.2, shuffle=True, random_state=42)

# %%
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    validation_split=0.2
)

test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
# Split the data into three categories.
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=False,
)
# Out:
# Found 6720 validated image filenames belonging to 525 classes.
# Found 1680 validated image filenames belonging to 525 classes.
# Found 2100 validated image filenames belonging to 515 classes.

# %%
# Data Augmentation Step
augment = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(224,224),
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.1),
])

# %%
# Load the pretained model
pretrained_model = tf.keras.applications.efficientnet.EfficientNetB0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='max'
)

pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
# Create checkpoint callback
checkpoint_path = "birds_classification_model_checkpoint"
checkpoint_callback = ModelCheckpoint(checkpoint_path,
                                      save_weights_only=True,
                                      monitor="val_accuracy",
                                      save_best_only=True)

# Setup EarlyStopping callback to stop training if model's val_loss doesn't improve for 3 epochs
early_stopping = EarlyStopping(monitor = "val_loss", # watch the val loss metric
                               patience = 5,
                               restore_best_weights = True) # if val loss decreases for 3 epochs in a row, stop training

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# %%
inputs = pretrained_model.input
x = augment(inputs)

x = Dense(128, activation='relu')(pretrained_model.output)
x = Dropout(0.45)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.45)(x)


outputs = Dense(525, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=Adam(0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    steps_per_epoch=len(train_images),
    validation_data=val_images,
    validation_steps=len(val_images),
    epochs=25,
    callbacks=[
        early_stopping,
        create_tensorboard_callback("training_logs",
                                    "bird_classification"),
        checkpoint_callback,
        reduce_lr
    ]
)
# Out:
# Saving TensorBoard log files to: training_logs/bird_classification/20240624-134442
# Epoch 1/25
# 210/210 [==============================] - 36s 113ms/step - loss: 6.5156 - accuracy: 0.0018 - val_loss: 6.2510 - val_accuracy: 0.0060 - lr: 1.0000e-04
# Epoch 2/25
# 210/210 [==============================] - 19s 89ms/step - loss: 6.2466 - accuracy: 0.0030 - val_loss: 6.2297 - val_accuracy: 0.0065 - lr: 1.0000e-04
# Epoch 3/25
# 210/210 [==============================] - 18s 87ms/step - loss: 6.2038 - accuracy: 0.0070 - val_loss: 6.1792 - val_accuracy: 0.0119 - lr: 1.0000e-04
# Epoch 4/25
# 210/210 [==============================] - 18s 88ms/step - loss: 6.1562 - accuracy: 0.0073 - val_loss: 6.0950 - val_accuracy: 0.0143 - lr: 1.0000e-04
# Epoch 5/25
# 210/210 [==============================] - 20s 96ms/step - loss: 6.0337 - accuracy: 0.0131 - val_loss: 5.9560 - val_accuracy: 0.0315 - lr: 1.0000e-04
# Epoch 6/25
# 210/210 [==============================] - 19s 88ms/step - loss: 5.9231 - accuracy: 0.0188 - val_loss: 5.7862 - val_accuracy: 0.0506 - lr: 1.0000e-04
# Epoch 7/25
# 210/210 [==============================] - 20s 97ms/step - loss: 5.7510 - accuracy: 0.0304 - val_loss: 5.5541 - val_accuracy: 0.0732 - lr: 1.0000e-04
# Epoch 8/25
# 210/210 [==============================] - 30s 145ms/step - loss: 5.5829 - accuracy: 0.0432 - val_loss: 5.3305 - val_accuracy: 0.0958 - lr: 1.0000e-04
# Epoch 9/25
# 210/210 [==============================] - 19s 92ms/step - loss: 5.3514 - accuracy: 0.0600 - val_loss: 5.0062 - val_accuracy: 0.1304 - lr: 1.0000e-04
# Epoch 10/25
# 210/210 [==============================] - 19s 91ms/step - loss: 5.1878 - accuracy: 0.0701 - val_loss: 4.7670 - val_accuracy: 0.1601 - lr: 1.0000e-04
# Epoch 11/25
# 210/210 [==============================] - 21s 98ms/step - loss: 5.0138 - accuracy: 0.0774 - val_loss: 4.5023 - val_accuracy: 0.2149 - lr: 1.0000e-04
# Epoch 12/25
# 210/210 [==============================] - 20s 97ms/step - loss: 4.8078 - accuracy: 0.0954 - val_loss: 4.2516 - val_accuracy: 0.2339 - lr: 1.0000e-04
# Epoch 13/25
# 210/210 [==============================] - 19s 90ms/step - loss: 4.6593 - accuracy: 0.1067 - val_loss: 4.0079 - val_accuracy: 0.2851 - lr: 1.0000e-04
# Epoch 14/25
# 210/210 [==============================] - 19s 89ms/step - loss: 4.4762 - accuracy: 0.1247 - val_loss: 3.7769 - val_accuracy: 0.3089 - lr: 1.0000e-04
# Epoch 15/25
# 210/210 [==============================] - 19s 92ms/step - loss: 4.3438 - accuracy: 0.1384 - val_loss: 3.5966 - val_accuracy: 0.3452 - lr: 1.0000e-04
# Epoch 16/25
# 210/210 [==============================] - 18s 88ms/step - loss: 4.2287 - accuracy: 0.1527 - val_loss: 3.4588 - val_accuracy: 0.3768 - lr: 1.0000e-04
# Epoch 17/25
# 210/210 [==============================] - 20s 96ms/step - loss: 4.0696 - accuracy: 0.1734 - val_loss: 3.3396 - val_accuracy: 0.3964 - lr: 1.0000e-04
# Epoch 18/25
# 210/210 [==============================] - 18s 87ms/step - loss: 3.9866 - accuracy: 0.1740 - val_loss: 3.1563 - val_accuracy: 0.4131 - lr: 1.0000e-04
# Epoch 19/25
# 210/210 [==============================] - 19s 90ms/step - loss: 3.8557 - accuracy: 0.1887 - val_loss: 2.9823 - val_accuracy: 0.4310 - lr: 1.0000e-04
# Epoch 20/25
# 210/210 [==============================] - 18s 88ms/step - loss: 3.7327 - accuracy: 0.2054 - val_loss: 2.9095 - val_accuracy: 0.4565 - lr: 1.0000e-04
# Epoch 21/25
# 210/210 [==============================] - 19s 88ms/step - loss: 3.6443 - accuracy: 0.2195 - val_loss: 2.8091 - val_accuracy: 0.4679 - lr: 1.0000e-04
# Epoch 22/25
# 210/210 [==============================] - 19s 91ms/step - loss: 3.5787 - accuracy: 0.2217 - val_loss: 2.6826 - val_accuracy: 0.4887 - lr: 1.0000e-04
# Epoch 23/25
# 210/210 [==============================] - 19s 88ms/step - loss: 3.4593 - accuracy: 0.2406 - val_loss: 2.6053 - val_accuracy: 0.4994 - lr: 1.0000e-04
# Epoch 24/25
# 210/210 [==============================] - 18s 87ms/step - loss: 3.3799 - accuracy: 0.2440 - val_loss: 2.5028 - val_accuracy: 0.5167 - lr: 1.0000e-04
# Epoch 25/25
# 210/210 [==============================] - 19s 90ms/step - loss: 3.3280 - accuracy: 0.2472 - val_loss: 2.3981 - val_accuracy: 0.5387 - lr: 1.0000e-04

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6ce884cdbab> in <cell line: 1>()
# ----> 1 results = model.evaluate(test_images, verbose=0)
#       2
#       3 print("    Test Loss: {:.5f}".format(results[0]))
#       4 print("Test Accuracy: {:.2f}%".format(results[1] * 100))
#
# NameError: name 'model' is not defined

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')

# %%
  # Display 25 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_df) - 1, 15)
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(25, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath.iloc[random_index[i]]))
    if test_df.Label.iloc[random_index[i]] == pred[random_index[i]]:
        color = "green"
    else:
        color = "red"
    ax.set_title(f"True: {test_df.Label.iloc[random_index[i]]}\nPredicted: {pred[random_index[i]]}", color=color)
plt.show()
plt.tight_layout()

# %%
y_test = list(test_df.Label)
print(classification_report(y_test, pred))

# %%
report = classification_report(y_test, pred, output_dict=True)
df = pd.DataFrame(report).transpose()
df

# %%
def get_img_array(img_path, size):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=size)
    array = tf.keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size "size"
    array = np.expand_dims(array, axis=0)
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]
    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = tf.keras.preprocessing.image.load_img(img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)
    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
#     display(Image(cam_path))

    return cam_path


preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input
decode_predictions = tf.keras.applications.mobilenet_v2.decode_predictions

last_conv_layer_name = "top_conv"
img_size = (224,224, 3)

# Remove last layer's softmax
model.layers[-1].activation = None

# %%
# Display the part of the pictures used by the neural network to classify the pictures
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    img_path = test_df.Filepath.iloc[random_index[i]]
    img_array = preprocess_input(get_img_array(img_path, size=img_size))
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
    cam_path = save_and_display_gradcam(img_path, heatmap)
    ax.imshow(plt.imread(cam_path))
    ax.set_title(f"True: {test_df.Label.iloc[random_index[i]]}\nPredicted: {pred[random_index[i]]}")
plt.tight_layout()
plt.show()
